# %% [markdown]
# <a href="https://colab.research.google.com/github/jukantirakeshkumar/machinelearning/blob/main/find-s%20for%20dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import csv


attributes = [['M','F'],
              ['very bad','bad','below average','average','good','excellent'],
              ['excellent','good','average','bad']]


num_attributes = len(attributes)


print (" \n The most general hypothesis : ['?','?','?','?','?','?']\n")
print ("\n The most specific hypothesis : ['0','0','0','0','0','0']\n")

a = []
print("\n The Given Training Data Set \n")

with open('/content/csv4.csv') as csvFile:
    reader = csv.reader(csvFile)
    for row in reader:
        a.append (row)
        print(row)


print("\n The initial value of hypothesis: ")
hypothesis = ['0'] * num_attributes
print(hypothesis)

# Comparing with First Training Example 
for j in range(0,num_attributes):
        hypothesis[j] = a[0][j];

# Comparing with Remaining Training Examples of Given Data Set

print("\n Find S: Finding a Maximally Specific Hypothesis\n")

for i in range(0,len(a)):
    if a[i][num_attributes]=='PASS':
            for j in range(0,num_attributes):
                if a[i][j]!=hypothesis[j]:
                    hypothesis[j]='?'
                else :
                    hypothesis[j]= a[i][j] 
    print(" For Training Example No :{0} the hypothesis is ".format(i),hypothesis)
                
print("\n The Maximally Specific Hypothesis for a given Training Examples :\n")
print(hypothesis)
# Out:
#
#  The most general hypothesis : ['?','?','?','?','?','?']
#
#
#  The most specific hypothesis : ['0','0','0','0','0','0']
#
#
#  The Given Training Data Set
#
# ['GENDER ', 'ASSIGNMENT', 'MARKS', 'RESULT']
# ['M', 'very bad', 'good', 'PASS']
# ['M', 'excellent', 'excellent', 'PASS']
# ['F', 'excellent', 'excellent', 'PASS']
# ['M', 'excellent', 'excellent', 'PASS']
# ['F', 'excellent', 'excellent', 'PASS']
# ['F', 'excellent', 'excellent', 'PASS']
# ['F', 'excellent', 'excellent', 'PASS']
# ['M', 'good', 'excellent', 'PASS']
# ['F', 'excellent', 'excellent', 'PASS']
# ['F', 'excellent', 'excellent', 'PASS']
# ['F', 'excellent', 'excellent', 'PASS']
# ['M', 'below average', 'average', 'FAIL']
# ['F', 'excellent', 'excellent', 'PASS']
# ['F', 'good', 'excellent', 'PASS']
# ['M', 'excellent', 'excellent', 'PASS']
# ['M', 'excellent', 'good', 'PASS']
# ['F', 'below average', 'excellent', 'PASS']
# ['F', 'excellent', 'excellent', 'PASS']
# ['M', 'average', 'excellent', 'PASS']
# ...

# %%
csv
